# %%
import re
import csv
from pydantic import BaseModel
from typing import List, Optional, Tuple

# %%
input_file = "output.md"
output_file = "cleaned_paper.csv"

# %% [markdown]
# ### Question Extraction

# %%
class Question(BaseModel):
    id: int
    question: str
    lead_in: str = ""
    option_A: str = "A"
    option_B: str = "B"
    option_C: str = "C"
    option_D: str = "D"
    option_E: str = "E"
    option_A_url: str = ""
    option_B_url: str = ""
    option_C_url: str = ""
    option_D_url: str = ""
    option_E_url: str = ""
    section_id: str="nvr"
    multiple_correct: str = "False"
    correct_option: str = "A"
    side_by_side: str = "True"

# %%
questions_data: List[Question] = []

# %%
QUESTION_SPLIT = re.compile(
    r'''
    (?:
        # ── HTML-wrapped number: must be ONLY digits
        <(?:p|b)>\s*(\d+)\s*</(?:p|b)>

      | # ── markdown bold number: must be ONLY digits
        \*\*\s*(\d+)\s*\*\*

      | # ── plain / heading number (line-based)
        ^\s*(?:\#+\s*)?
        (\d+)
        (?!\.)
        (?:
            \s*$                # number-only line
          | \s+(?!\d)            # not a sequence
             (?!cm\b|mm\b|m\b|kg\b|g\b|%)
          | \n+
        )
    )
    ''',
    re.VERBOSE | re.MULTILINE | re.IGNORECASE
)




SPLIT_HEADING = re.compile(
    r'(\n#{1,3}\s+(?=.*[A-Za-z])[^\n]+\n)'
)

# %%
def extract_questions(text):
    splits = QUESTION_SPLIT.split(text)
    results = []

    i = 1
    while i < len(splits):
        group = splits[i:i+3]
        q_num = next((g for g in group if g is not None), None)
        block = splits[i + 3] if i + 3 < len(splits) else ""

        if q_num:
            results.append((q_num.strip(), block.strip()))

        i += 4

    return results

# %%
with open(input_file, 'r', encoding='utf-8') as f:
    content = f.read()

# %%
parts = SPLIT_HEADING.split(content)

# Reattach heading + content
sections = []
i = 0
while i < len(parts):
    if parts[i].startswith('\n#'):
        heading = parts[i].strip()
        content = parts[i + 1].strip() if i + 1 < len(parts) else ""
        sections.append((heading, content))
        i += 2
    else:
        i += 1

for h, c in sections:
    print("HEADING", h)
    # print(c)
    print(*extract_questions(c), sep='\n')
# Out:
# HEADING # ENGLISH
#
# HEADING ## The Strange Case of Dr Jekyll and Mr Hyde
# ('1', 'In which city is the novel set?\n\n- A London\n- B Manchester\n- C Birmingham\n- D Oxford\n- E Cambridge')
# ('2', 'What type of word is "ferocity" (line 2)?\n\n- A noun\n- B preposition\n- C verb\n- D adverb\n- E adjective')
# ('3', 'The victim of the crime is described as being of “high position” (line 2). What does this mean?\n\n- A that he was on a high platform when the crime occurred\n- B that he was a man of the upper classes\n- C that he always held his head up high\n- D that he was rich\n- E that he was a man of the lower classes')
# ('4', 'What time did the maid go to bed?\n\n- A 9pm\n- B 10pm\n- C 11pm\n- D midnight\n- E 1am')
# ('5', 'What literary technique is being used in the line “a fog rolled over the city” (line 4)?\n\n- A simile\n- B metaphor\n- C rhetorical question\n- D personification\n- E oxymoron')
# ('6', 'What types of word are “drawing” (line 10), “advancing” (line 11), and “bowed” (line 13)?\n\n- A nouns\n- B prepositions\n- C verbs\n- D adverbs\n- E adjectives')
# ('7', 'How many adjectives are used to describe the older man in line 10?\n\n- A 1\n- B 2\n- C 3\n- D 4\n- E 5')
# ('8', '**What literary technique is being used in this phrase: “but the moon shone on his face as he spoke, and the girl was pleased to watch it, it seemed to breathe such an innocent and old-world kindness of disposition” (lines 15-17)?**\n\n- A simile\n- B metaphor\n- C rhetorical question\n- D personification\n- E oxymoron')
# ('9', "**What is a “disposition” (line 17)?**\n\n- A someone's face\n- B the act of taking a monarch from their throne\n- C when someone is moved from where they were standing before\n- D the place in which someone is standing or sitting\n- E someone's personality or character")
# ('10', '**What literary technique is being used in this phrase “her eye wandered to the other” (line 18)?**\n\n- A simile\n- B metaphor\n- C rhetorical question\n- D personification\n- E oxymoron')
# ('11', '**What does it tell us about the way the maid looked at the other man?**\n\n- A that she did so quickly\n- B that she liked him\n- C that she disliked him\n- D that she did so without thinking about it\n- E that she did so slowly')
# ('12', '**How does the maid feel about Mr Hyde?**\n\n- A She is afraid of him.\n- B She finds him tolerable.\n- C She likes him.\n- D She has no opinion of him.\n- E She dislikes him.')
# ('13', 'What does the metaphor “he broke out in a great flame of anger” (lines 21-22) tell us about Mr Hyde’s feelings?\n\n- A that he is feeling a great, passionate rage\n- B that his is calm and in control\n- C that he is excited\n- D that he is mildly irritated\n- E that he is filled with hatred')
# ('14', 'What literary method is being used in the following phrase: “carrying on (as the maid described it) like a madman” (line 23)?\n\n- A simile\n- B metaphor\n- C rhetorical question\n- D personification\n- E oxymoron')
# ('15', 'After the first attack, the victim is described as being “a trifle hurt” (line 24). What does this mean?\n\n- A that he is very badly hurt\n- B that he is not hurt at all\n- C that he is dying\n- D that he is a little bit hurt\n- E that he is making a lot of noise about being hurt')
# ('16', 'Why does the writer use animal imagery in the simile “ape-like fury” (line 25) and “trampling” (line 26) in his description of the attack?\n\n- A because it helps to describe the crime\n- B because animals are stronger than humans\n- C because Mr Hyde was pretending to be an animal during the attack\n- D because readers like to read about animals\n- E because it shows that Mr Hyde was more like an animal than a human being in that moment')
# ('17', 'Similarly, the writer uses another kind of imagery to describe the nature of the attack what type of imagery is it?\n\n- A blood\n- B weather\n- C colour\n- D nature\n- E wealth')
# ('18', 'What did the maid do immediately after the attack?\n\n- A She tried to save the victim.\n- B She called the police.\n- C She chased after Mr Hyde.\n- D She fainted.\n- E She screamed.')
# ('19', 'How many adjectives are there in the second paragraph?\n\n- A 8\n- B 9\n- C 10\n- D 11\n- E 12')
# ('20', 'What happened to the murder weapon?\n\n- A It broke.\n- B It was taken away by Mr Hyde.\n- C It was left behind.\n- D It was thrown into the river.\n- E It was hidden.')
# ('21', 'What words best summarise Mr Hyde?\n\n- A cold, quiet, villainous\n- B evil, murderous, angry\n- C sly, calm, calculating\n- D awkward, irritable, misunderstood\n- E likeable, amiable, kind')
# ('22', '**What is the profession of Mr Utterson?**\n\n- A doctor\n- B teacher\n- C lawyer\n- D police officer\n- E sergeant')
# ('23', "**How does Mr Utterson feel about the crime?**\n\n- A He is serious and somewhat mournful.\n- B He doesn't care about it.\n- C He is excited about it.\n- D He is very sad.\n- E He is angry.")
# ('24', '**Which words tell the reader this?**\n\n- A morning, lip\n- B shot, serious\n- C kindness, hurried\n- D drove, nodded\n- E solemn, grave')
# ('25', '**What type of word is “countenance” (line 40)?**\n\n- A noun\n- B adjective\n- C verb\n- D adverb\n- E preposition')
# ('26', '**What does it mean?**\n\n- A imagination\n- B thoughts\n- C feelings\n- D attitude\n- E facial expression')
# ('27', '**Why does the officer\'s eye light up "with professional ambition" (line 45)?**\n\n- A He is wants to show off to Mr Utterson.\n- B He doesn\'t care about the victim or the case.\n- C He cares deeply about justice.\n- D He sees an opportunity for recognition in his job.\n- E He cares deeply about the victim.')
# ('28', '**What is meant by the phrase "This will make a great deal of noise" (line 45)?**\n\n- A The death is going to get a lot of attention from the public.\n- B There will be riots and demonstrations over the death.\n- C The police station is going to be busy and loud.\n- D The police will have to make a lot of noise to solve the murder.\n- E No one will care about the death.')
# HEADING ### Spelling Exercises
# ('29', 'The business accumulated an overwhelming amount of debt whilst it was running.  \nA B C D')
# ('30', "A psychiatrists' job is to assess patients' mental health and diagnose disorders.  \nA B C D")
# ('31', 'The witness testified that he had never seen the defendant before in his life.  \nA B C D')
# ('32', 'The competition winners were invited to see the world premiere of the new movie.  \nA B C D')
# ('33', 'His extensive experience means that he is the most suitable candidate for the job.  \nA B C D')
# ('34', "The map illustrated the community's cultural diversity in terms of cuisine.  \nA B C D")
# ('35', 'An eerie disquiet descended upon the lake, over which a viscoid fog hovered.  \nA B C D')
# ('36', "The Queen's platinum jubilee celebrates the 70th anniversary of her coronation.  \nA B C D")
# ('37', 'After the console was damaged, it was reset to the default factory configuration.  \nA B C D')
# HEADING ### Kingdom Hearts
# ('38', '*Kingdom Hearts* is a video game franchise created and published by Square-Enix\n\nImage: Sentence 38 with arrows pointing to words for marking: A (Kingdom Hearts), B (a), C (created), D (by Square-Enix).')
# ('39', 'collaboration with Disney The first game was released on PlayStation 2 in 2002, and\n\nImage: Sentence 39 with arrows pointing to words for marking: A (collaboration), B (The), C (released), D (and).')
# ('40', 'tells the story of Sora, a boy living on an island with his friends; Kairi and Riku. One\n\nImage: Sentence 40 with arrows pointing to words for marking: A (tells), B (a), C (with), D (One).')
# ('41', 'night, an enormous shadow monster attacks their home, before the island is\n\nImage: Sentence 41 with arrows pointing to words for marking: A (night), B (attacks), C (before), D (is).')
# ('42', 'swallowed up by darkness. Sora, must travel to different worlds from Disney films\n\nImage: Sentence 42 with arrows pointing to words for marking: A (swallowed), B (must), C (from), D (films).')
# ('43', '(such as Neverland from Peter Pan, and the jungle from Tarzan with his\n\nImage: Sentence 43 with arrows pointing to words for marking: A (such), B (and), C (from), D (with).')
# ('44', "companion's, Donald Duck and Goofy, to lock them with his magical weapon, the\n\nImage: Sentence 44 with arrows pointing to words for marking: A (companion's), B (and), C (with), D (the).")
# ('45', 'Keyblade, whilst also searching for the lost kairi and Riku. The first game spawned\n\nImage: Sentence 45 with arrows pointing to words for marking: A (Keyblade), B (searching), C (the), D (spawned).')
# ('46', "several sequels and a range of merchandise, such as comic books and figurine's.\n\nImage: Sentence 46 with arrows pointing to words for marking: A (several), B (a), C (such), D (figurine's).\n\nIn this passage you have to choose the **best** word, or **group of words**, to complete each numbered line so that it makes sense and is written in correct English. Choose the **best** answer and mark its letter on your answer sheet.")
# HEADING ### What Zack Was Waiting For
# ('47', "A\n\nB\n\nC\n\nD\n\nE\n\nBut that didn't mean that he enjoyed it.\n\nHe scrolled aimlessly")
# ('48', "A\n\nB\n\nC\n\nD\n\nE\n\nhis phone, but it presented him with nothing to allay his fears. His mind flushed with panic, and he decided he couldn't wait any longer. He")
# ('49', "A\n\nB\n\nC\n\nD\n\nE\n\nhis phone, grabbed his bag and left his house.\n\nIt didn't")
# ('50', 'A\n\nB\n\nC\n\nD\n\nE\n\nhim long to reach his destination. The place loomed')
# ('51', 'A\n\nB\n\nC\n\nD\n\nE\n\nhim as if in mockery of his feelings of anxiety that twisted his stomach into knots. He ignored it and stepped inside.\n\nThe man with the')
# ('52', '|      |        |         |        |       |\n|------|--------|---------|--------|-------|\n| miss | misses | missing | missed | miser |\n| A    | B      | C       | D      | E     |\n\nteeth grinned at him expectantly.')
# ('53', '|         |       |      |         |         |\n|---------|-------|------|---------|---------|\n| "You\'re | "Your | "You | "You is | "You am |\n| A       | B     | C    | D       | E       |\n\nhere," he commented. "And so is this. Looks like your wait is over."\n\nAnd he handed Zack the thing he')
# ('54', '|     |      |     |    |     |\n|-----|------|-----|----|-----|\n| has | have | had | is | was |\n| A   | B    | C   | D  | E   |\n\nbeen waiting for: the newest edition of The Amazing Spider-man comic book.')
# HEADING ## VERBAL REASONING
# ('1', 'You must put your plates in the sink now.\n\n- A you must\n- B must put\n- C put your\n- D plates in\n- E sink now')
# ('2', 'Being willing to help out is a good character trait.\n\n- A being willing\n- B to help\n- C help out\n- D a good\n- E character trait')
# ('3', 'The winter weather was raw and cold.\n\n- A the weather\n- B weather was\n- C was raw\n- D raw and\n- E and cold')
# ('4', 'The camera can zoom into the small details.\n\n- A the camera\n- B can zoom\n- C zoom into\n- D into the\n- E small details')
# ('5', 'The village was in the snowy mountains.\n\n- A the village\n- B village was\n- C was in\n- D the snowy\n- E snowy mountains')
# ('6', "It is not exactly true that carrots make you see in the dark.\n\n- A it is\n- B not exactly\n- C true that\n- D carrots make\n- E the dark\n\nIn these questions, find **two** words, **one** from each group, that are **most opposite in meaning**. Mark **both** words on the answer sheet.\n\nExample (morning early wake)\n\n(late shop dark)\n\n- A morning\n- B early\n- C wake\n\n- X late\n- Y shop\n- Z dark\n\nAnswer early late\n\nSolution The two words, one from each group, that are **most opposite in meaning** are 'early' from group one and 'late' from group two.")
# ('7', '(popular courage strong)\n\n(fear doubt worried)\n\n- A popular\n- B courage\n- C strong\n\n- X fear\n- Y doubt\n- Z worried')
# ('8', '(carefree careful sure)\n\n(ignorant lonely reckless)\n\n- A carefree\n- B careful\n- C sure\n\n- X ignorant\n- Y lonely\n- Z reckless')
# ('9', '(absent foolish isolated)\n\n(wise bright friendly)\n\n- A absent\n- B foolish\n- C isolated\n\n- X wise\n- Y bright\n- Z friendly')
# ('10', '(mild full generous)\n\n(mean bite demanding)\n\n- A mild\n- B full\n- C generous\n\n- X mean\n- Y bite\n- Z demanding')
# ('11', '(forgiving famous kind)\n\n(unknown boring doubtful)\n\n- A forgiving\n- B famous\n- C kind\n\n- X unknown\n- Y boring\n- Z doubtful')
# ('12', '(dew thawed warm)\n\n- A dew\n- B thawed\n- C warm\n\n(fresh cold froze)\n\n- X fresh\n- Y cold\n- Z froze\n\nIn each question, find the number that continues the series in the most sensible way and mark it on the answer sheet.\n\n**Example** 2 4 6 8 [ ? ]\n\n- A 16\n- B 11\n- C 10\n- D 9\n- E 12\n\n**Answer')
# ('10', 'Solution** In this series, you add 2 each time. For other series, you might have to perform a different sort of operation (+, -,  $\\times$ ,  $\\div$ ). There might also be two series involved: the first comprising the 1<sup>st</sup>, 3<sup>rd</sup>, 5<sup>th</sup> number etc. and the second comprising the 2<sup>nd</sup>, 4<sup>th</sup>, 6<sup>th</sup> etc.')
# ('13', '4 8 12 16 20 [ ? ]\n\n- A 19\n- B 25\n- C 21\n- D 24\n- E 30')
# ('14', '3125 625 125 25 [ ? ]\n\n- A 3\n- B 10\n- C 5\n- D 8\n- E 6')
# ('15', '1 3 5 7 2 4 6 [ ? ]\n\n- A 10\n- B 1\n- C 5\n- D 6\n- E 8')
# ('16', '2 3 4 6 8 [?]\n\nA 44\n\nB 24\n\nC 64\n\nD 12\n\nE 28')
# ('17', '8 11 14 17 20 [?]\n\nA 23\n\nB 20\n\nC 22\n\nD 21\n\nE 36')
# ('18', "67 63 59 55 51 [?]\n\nA 40\n\nB 47\n\nC 39\n\nD 25\n\nE 50\n\nIn these sentences, the word in capitals has had three letters next to each other taken out. These three letters will make one correctly spelt word without changing their order.\n\nThe sentence that you make must make sense.\n\nMark the correct three-letter word on the answer sheet.\n\n**Example** The cat scratched him with his **CS**.\n\nA LAD\n\nB LAW\n\nC HAD\n\nD RAW\n\nE RED\n\n**Answer** LAW\n\n**Solution** The three-letter word that has been removed from CS is 'LAW'. If we place this three-letter word between C and S, it makes the word **CLAWS** and thus completes the sentence.")
# ('19', 'Some people BEVE in superstitions.\n\nA ROE\n\nB TAY\n\nC LIE\n\nD ARE\n\nE OST')
# ('20', 'The troops made an ADCE toward enemy lines.\n\nA TIP\n\nB VAN\n\nC SHO\n\nD BIN\n\nE OAT')
# ('21', 'Nitrogen is an ELET on the periodic table.\n\nA BIT\n\nB OPE\n\nC AME\n\nD MEN\n\nE ICH')
# ('22', 'It is good to go to sleep at EXLY the same time each evening.\n\nA ACT\n\nB SIE\n\nC IVE\n\nD EST\n\nE OPE')
# ('23', 'The number ten is GRER than the number nine.\n\nAOLF\n\nB ASE\n\nC BON\n\nD EAT\n\nE IDO')
# ('24', "I ASMED you would not be coming to the party.\n\nALL\n\nB AME\n\nC SUM\n\nD TOP\n\nE RIN\n\nIn these questions, one letter can be moved from the first word to the second word to make two new words.\n\nThe letters must not otherwise be rearranged and both new words must make sense. Find the letter that moves and mark it on the answer sheet.\n\nExample pound or\n\nA p\n\nB o\n\nC u\n\nD n\n\nE c\n\nAnswer u\n\nSolution The answer is u: when removed from the word 'pound', we get a new word 'pond' and when added to the word 'or' we get a new word 'our'. The letters have not otherwise been rearranged and both new words make sense.")
# ('25', 'shine \xa0\xa0\xa0\xa0 at\n\nA s\n\nB e\n\nC h\n\nD N\n\nE i')
# ('26', 'hero \xa0\xa0\xa0\xa0 live\n\nA o\n\nB r\n\nC h\n\nD E\n\nE l')
# ('27', 'cable \xa0\xa0\xa0\xa0 are\n\nA A\n\nB c\n\nC l\n\nD e\n\nE B')
# ('28', 'mother \xa0\xa0\xa0\xa0 oats\n\nA t\n\nB o\n\nC m\n\nD h\n\nE r')
# ('29', 'block \xa0\xa0\xa0\xa0 rain\n\nA L\n\nB b\n\nC o\n\nD k\n\nE c')
# ('30', "flame \xa0\xa0\xa0\xa0 ail\n\nA f\n\nB l\n\nC a\n\nD e\n\nE m\n\nIn these questions, find the two words, one from each group, that will complete the sentence in the best way.\n\nMark both words on the answer sheet.\n\n**Example** \xa0\xa0 **Big** is to (small \xa0\xa0 orange \xa0\xa0 colour) as **wide** is to (apple \xa0\xa0 red \xa0\xa0 narrow).\n\n|             |             |\n|-------------|-------------|\n| A \xa0\xa0 small  | X \xa0\xa0 apple  |\n| B \xa0\xa0 orange | Y \xa0\xa0 red    |\n| C \xa0\xa0 colour | Z \xa0\xa0 narrow |\n\n**Answer** \xa0\xa0 **small \xa0\xa0 narrow**\n\n**Solution** \xa0\xa0 In this example, 'big' is to **small** as 'wide' is to **narrow** is correct because the word relationships here are antonyms (opposites). For other questions, the word relationship will be something different (pay attention to word type as well as meaning) but the important thing to remember is that the first relationship will connect with the second relationship.")
# ('31', 'Messy is to (untidy neglected old) as happy is to (successful pretty content).\n\n|                |                 |\n|----------------|-----------------|\n| A \xa0\xa0 untidy    | X \xa0\xa0 successful |\n| B \xa0\xa0 neglected | Y \xa0\xa0 pretty     |\n| C \xa0\xa0 old       | Z \xa0\xa0 content    |')
# ('32', 'Absent is to (present \xa0\xa0 missing \xa0\xa0 clear) as kind is to (happy \xa0\xa0 mean \xa0\xa0 hopeful).\n\n|              |              |\n|--------------|--------------|\n| A \xa0\xa0 present | X \xa0\xa0 happy   |\n| B \xa0\xa0 missing | Y \xa0\xa0 mean    |\n| C \xa0\xa0 clear   | Z \xa0\xa0 hopeful |')
# ('33', 'Sunny is to (warm \xa0\xa0 friendly \xa0\xa0 deep) as ocean is to (thick \xa0\xa0 blue \xa0\xa0 old).\n\n|               |            |\n|---------------|------------|\n| A \xa0\xa0 warm     | X \xa0\xa0 thick |\n| B \xa0\xa0 friendly | Y \xa0\xa0 blue  |\n| C \xa0\xa0 deep     | Z \xa0\xa0 old   |')
# ('34', 'Hygiene is to (cold \xa0\xa0 blunt \xa0\xa0 clean) as birthday is to (difficult \xa0\xa0 ancient \xa0\xa0 candles).\n\n|            |                |\n|------------|----------------|\n| A \xa0\xa0 cold  | X \xa0\xa0 difficult |\n| B \xa0\xa0 blunt | Y \xa0\xa0 ancient   |\n| C \xa0\xa0 clean | Z \xa0\xa0 candles   |')
# ('35', 'Forgive is to (peace hate blame) as honest is to (deceit friend compassion).\n\n|   |       |   |            |\n|---|-------|---|------------|\n| A | peace | X | deceit     |\n| B | hate  | Y | friend     |\n| C | blame | Z | compassion |')
# ('36', "Natural is to (organic strange leaf) as attractive is to (appear life pleasant).\n\n|   |         |   |          |\n|---|---------|---|----------|\n| A | organic | X | appear   |\n| B | strange | Y | life     |\n| C | leaf    | Z | pleasant |\n\nIn these questions, three of the five words are related in some way.\n\nFind the **two** words that do not go with these three and mark them **both** on the answer sheet.\n\n|         |       |       |       |       |       |\n|---------|-------|-------|-------|-------|-------|\n| Example | Black | Mouse | red   | green | Hut   |\n| A       | black | B     | mouse | C     | red   |\n|         |       |       |       | D     | green |\n|         |       |       |       |       | E     |\n|         |       |       |       |       | hut   |\n\nAnswer mouse hut\n\n**Solution** The words 'black', 'red' and 'green' are related because they are all colours; the words '**mouse**' and '**hut**' do not go with these three words.")
# ('37', 'square \xa0 circle \xa0 big \xa0 brown \xa0 triangle  \nA square \xa0 B circle \xa0 C big \xa0 D brown \xa0 E triangle')
# ('38', '|         |            |         |          |        |\n|---------|------------|---------|----------|--------|\n| table   | cupboard   | chair   | pretty   | thin   |\n| A table | B cupboard | C chair | D pretty | E thin |')
# ('39', '|   |        |        |        |       |       |   |       |   |       |\n|---|--------|--------|--------|-------|-------|---|-------|---|-------|\n|   | potato | window | corn   | house | beans |   |       |   |       |\n| A | potato | B      | window | C     | corn  | D | house | E | beans |')
# ('40', '|   |     |      |      |      |         |   |      |   |         |\n|---|-----|------|------|------|---------|---|------|---|---------|\n|   | bus | bike | car  | taxi | bicycle |   |      |   |         |\n| A | bus | B    | bike | C    | car     | D | taxi | E | bicycle |')
# ('41', '|   |         |       |       |        |          |   |        |   |          |\n|---|---------|-------|-------|--------|----------|---|--------|---|----------|\n|   | teacher | pupil | paper | parent | customer |   |        |   |          |\n| A | teacher | B     | pupil | C      | paper    | D | parent | E | customer |')
# ('42', "|   |        |      |      |        |      |   |        |   |     |\n|---|--------|------|------|--------|------|---|--------|---|-----|\n|   | street | wide | thin | narrow | hat  |   |        |   |     |\n| A | street | B    | wide | C      | thin | D | narrow | E | Hat |\n\nThese questions contain three pairs of words.\n\nFind the word that completes the last pair of words in the **same way** as the other two pairs. Mark it on the answer sheet.\n\n**Example** (band ban) (song son) (tear [ ? ])  \nA ear B tea C tar D are E eat\n\n**Answer** tea\n\n**Solution** In the first two pairs of words, the second word has been made from the first three letters of 'band' to make the word 'ban'. Likewise in the second pair of words, 'song' makes the word 'son'. If you apply the same rule to the third pair of words, you get the answer 'tea'.")
# ('43', '(rate rat)\n\nA ank\n\n(area are)\n\nB arn\n\nC urn\n\n(rank [?])\n\nD ran\n\nE nar')
# ('44', '(hope hop)\n\nA net\n\n(bare bar)\n\nB ted\n\nC ten\n\n(tend [?])\n\nD den\n\nE det')
# ('45', '(bind bin)\n\nA lad\n\n(ramp ram)\n\nB lay\n\nC day\n\n(lady [?])\n\nD dal\n\nE ald')
# ('46', '(tear tea)\n\nA rof\n\n(earn ear)\n\nB for\n\nC fon\n\n(form [?])\n\nD rom\n\nE fro')
# ('47', '(sage sag)\n\nA dea\n\n(farm far)\n\nB dem\n\nC dam\n\n(made [?])\n\nD med\n\nE mad')
# ('48', '(your you)\n\nA See\n\n(huge hug)\n\nB sep\n\nC pes\n\n(seep [?])\n\nD pep\n\nE pes')
# ('49', "Read the following information, then find the correct answer to the question and mark its letter on the answer sheet.\n\nDavid, Frank, and Jemma prefer grapes to apples.  \nMaria and Charlie both prefer bananas.  \nDavid's favourite fruit is mango and Jemma's favourite fruit is pineapple.  \nMaria does not eat mango.  \nCharlie likes mango but not pineapple.  \nIf these statements are true, only one of the sentences below **can** be true.\n\nWhich one?\n\n- A David and Maria like mango\n- B Frank prefers grapes to apples\n- C Jemma and Charlie both like pineapple\n- D David, Maria, and Charlie do not like pineapple\n- E Frank likes apples most")
# ('50', 'Read the following information, then find the correct answer to the question and mark its letter on the answer sheet.\n\nHorses, cats, and bears are mammals.  \nRats are mammals and rodents.  \nCats and tigers are felines and mammals.  \nLizards are reptiles, as are crocodiles.  \nBirds are mammals and vertebrates.  \nBears are vertebrates.  \nIf these statements are true, only one of the sentences below **cannot** be true.\n\nWhich one?\n\n- A Birds are not mammals\n- B Tigers are feline reptiles\n- C Bears, horses, and birds are mammals\n- D Birds and rats are rodents')
# HEADING ## MATHEMATICS
# ('1', 'Lucas and Ethan are brothers. Ethan is three times as old as Lucas. The sum of their ages is 36 years. How old was Ethan four years ago?\n\nA. 25 years \xa0\xa0 B. 28 years \xa0\xa0 C. 23 years \xa0\xa0 D. 24 years \xa0\xa0 E. 27 years')
# ('2', 'Here are the scores of students in a quiz :\n\n12 10 15 20 18 14 16 15 12 17  \n19 13 14 15 16 18 12 17 16 15\n\nWhat is the mean score?\n\nA. 16.5 \xa0\xa0 B. 15.7 \xa0\xa0 C. 16.2 \xa0\xa0 D. 17.5 \xa0\xa0 E. 15.2')
# ('3', 'I think of a number. I subtract 6 from my number and then I double the result. The final result is 22. What was the number I started with?\n\nA. 19 \xa0\xa0 B. 15 \xa0\xa0 C. 18 \xa0\xa0 D. 17 \xa0\xa0 E. 20')
# ('4', 'At a theme park, an adult ticket costs £15.50, and a child ticket costs £8.00. A family ticket for 2 adults and 3 children is £50.\n\nHow much money do you save by buying the family ticket instead of individual tickets?\n\nA. £10 \xa0\xa0 B. £5 \xa0\xa0 C. £8 \xa0\xa0 D. £12 \xa0\xa0 E. £6')
# ('5', 'Work out the difference between each pair of times.\n\n![An analog clock face showing the time 1:10. The hour hand is slightly past the 1, and the minute hand is on the 2.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637959/ls22ngzafr38cmlqnjgr.jpg)\n\nAn analog clock face showing the time 1:10. The hour hand is slightly past the 1, and the minute hand is on the 2.\n\n![An analog clock face showing the time 3:30. The hour hand is halfway between the 3 and the 4, and the minute hand is on the 6.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637924/xj0qmucphtsw0okrxuho.jpg)\n\nAn analog clock face showing the time 3:30. The hour hand is halfway between the 3 and the 4, and the minute hand is on the 6.\n\nWhat is the answer in hours and minutes?\n\nA. 2:45 \xa0\xa0 B. 3.55 \xa0\xa0 C. 2:40 \xa0\xa0 D. 3:35 \xa0\xa0 E. 2:55')
# ('6', 'Jack and Lily are arranging their books on a shelf. Jack has 56 books, and Lily has 84 books. They want to arrange the books in rows with an equal number of books in each row, such that both Jack and Lily have the same number of books per row. What is the greatest number of books that can be in each row?\n\nA. 18 \xa0\xa0\xa0\xa0 B. 26 \xa0\xa0\xa0\xa0 C. 24 \xa0\xa0\xa0\xa0 D. 28 \xa0\xa0\xa0\xa0 E. 14')
# ('7', 'Sarah had 20 apples in a box. She gave 12 apples to her friend. What percentage of apples does Sarah have left?\n\n![A box containing 20 red apples arranged in 4 rows of 5 apples each.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637988/wy3c81v1vcywmyhbo613.jpg)\n\nA box containing 20 red apples arranged in 4 rows of 5 apples each.\n\nA. 30% \xa0\xa0\xa0\xa0 B. 40% \xa0\xa0\xa0\xa0 C. 25% \xa0\xa0\xa0\xa0 D. 50% \xa0\xa0\xa0\xa0 E. 35%')
# ('8', "The arrow shows how much the sack of sugar weighs.\n\n![A diagram showing a sack of sugar on a scale. The scale has a rectangular base divided into 10 equal vertical segments. The first 4 segments are labeled '8 kg' and the next 5 segments are labeled '9 kg'. An arrow points from the sack of sugar down to the 5th segment of the scale.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637989/gh7ztyizgujyxomdui1u.jpg)\n\nA diagram showing a sack of sugar on a scale. The scale has a rectangular base divided into 10 equal vertical segments. The first 4 segments are labeled '8 kg' and the next 5 segments are labeled '9 kg'. An arrow points from the sack of sugar down to the 5th segment of the scale.\n\nIf another 600g sugar are added, what will the total weight be?\n\nA. 9.2 kg \xa0\xa0\xa0\xa0 B. 9.0 kg \xa0\xa0\xa0\xa0 C. 9.4 kg \xa0\xa0\xa0\xa0 D. 9.6 kg \xa0\xa0\xa0\xa0 E. 9.3 kg")
# ('9', 'In a football match, Alex scored 40% of the total points for the team. If the team scored 200 points in total, how many points did the rest of the team score?\n\nA. 100 \xa0\xa0\xa0\xa0 B. 140 \xa0\xa0\xa0\xa0 C. 110 \xa0\xa0\xa0\xa0 D. 150 \xa0\xa0\xa0\xa0 E. 120')
# ('10', 'David is making a smoothie. He uses fruit, yogurt, and honey in a ratio of 4 : 3 : 1. If David uses 12 grams of honey, how many grams of fruit does he use?\n\nA. 48 grams \xa0\xa0\xa0\xa0 B. 36 grams \xa0\xa0\xa0\xa0 C. 24 grams \xa0\xa0\xa0\xa0 D. 54 grams \xa0\xa0\xa0\xa0 E. 60 grams')
# ('11', 'Mr. Smith compares the price of the same table lamps at five different shops:\n\n| Name   | Price                   |\n|--------|-------------------------|\n| Shop P | £60 with a 25% discount |\n| Shop Q | £35 with a 10% discount |\n| Shop R | £45                     |\n| Shop S | 3 for £105              |\n| Shop T | 2 for £80               |\n\nWhich shop offers the cheapest cost per lamp?\n\nA. R \xa0\xa0\xa0\xa0 B. T \xa0\xa0\xa0\xa0 C. S \xa0\xa0\xa0\xa0 D. Q \xa0\xa0\xa0\xa0 E. P')
# ('12', "Liam's curfew is at 22:30. He goes out to play with his friends at quarter past seven in the evening. How long does Liam play with his friends for (answer in minutes)?\n\nA. 180 \xa0\xa0\xa0\xa0 B. 160 \xa0\xa0\xa0\xa0 C. 190 \xa0\xa0\xa0\xa0 D. 200 \xa0\xa0\xa0\xa0 E. 195")
# ('13', 'The trip from Bristol to Edinburgh takes 5 hours when traveling at a constant speed of 50 miles per hour. How long does the trip take when traveling at a constant speed of 40 miles per hour?\n\nA. 6.25 hours \xa0\xa0\xa0\xa0 B. 5.5 hours \xa0\xa0\xa0\xa0 C. 6 hours \xa0\xa0\xa0\xa0 D. 5.25 hours \xa0\xa0\xa0\xa0 E. 5.15 hours.')
# ('14', 'This is a plan of a hallway.\n\n![A plan of a hallway shown as a polygon with dimensions. The top horizontal edge is 12 m. The left vertical edge is 4 m. A horizontal edge of 3 m extends from the right side of the 4 m edge. A vertical edge of 5 m extends downwards from the end of the 3 m edge. A horizontal edge of 4 m extends to the right from the bottom of the 5 m edge. The total width of the hallway is 12 m + 4 m = 16 m. The total height is 4 m + 5 m = 9 m. The area is 16 m * 9 m = 144 m².](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637986/bdyifbp6tv0lxvtw0zte.jpg)\n\nThe plan shows a hallway with the following dimensions: top horizontal edge is 12 m, left vertical edge is 4 m, a horizontal edge of 3 m extends from the right side of the 4 m edge, a vertical edge of 5 m extends downwards from the end of the 3 m edge, and a horizontal edge of 4 m extends to the right from the bottom of the 5 m edge. The total width is 12 m + 4 m = 16 m, and the total height is 4 m + 5 m = 9 m. The area is 16 m \\* 9 m = 144 m².\n\nA plan of a hallway shown as a polygon with dimensions. The top horizontal edge is 12 m. The left vertical edge is 4 m. A horizontal edge of 3 m extends from the right side of the 4 m edge. A vertical edge of 5 m extends downwards from the end of the 3 m edge. A horizontal edge of 4 m extends to the right from the bottom of the 5 m edge. The total width of the hallway is 12 m + 4 m = 16 m. The total height is 4 m + 5 m = 9 m. The area is 16 m \\* 9 m = 144 m².\n\nWork out how many square metres of carpet are needed to cover it.\n\nA. 89m<sup>2</sup> \xa0\xa0\xa0\xa0 B. 72m<sup>2</sup> \xa0\xa0\xa0\xa0 C. 59m<sup>2</sup> \xa0\xa0\xa0\xa0 D. 67m<sup>2</sup> \xa0\xa0\xa0\xa0 E. 77m<sup>2</sup>')
# ('15', 'Sarah collected the following data during a survey of her friends (100 pupils).\n\n| Hobby |       |        |         |\n|-------|-------|--------|---------|\n|       | Music | Sports | Reading |\n| Boys  | 18    | 21     | 16      |\n| Girls | 15    | ?      | 10      |\n\nShe recorded how many boys and girls chose different hobbies, as shown in a table or chart. How many girls chose “sports” as their favourite hobby?\n\nA. 24 \xa0\xa0\xa0\xa0 B. 19 \xa0\xa0\xa0\xa0 C. 21 \xa0\xa0\xa0\xa0 D. 20 \xa0\xa0\xa0\xa0 E. 22')
# ('16', 'A packet of crisps costs £1.20 and a bottle of juice costs £2.50. Tom buys 5 packets of crisps and 3 bottles of juice. What is the total cost of his purchase?\n\nA. £15.50 \xa0\xa0\xa0\xa0 B. £13.50 \xa0\xa0\xa0\xa0 C. £15.00 \xa0\xa0\xa0\xa0 D. £16.50 \xa0\xa0\xa0\xa0 E. £12.75')
# ('17', 'Jason and Emma live 50 miles apart. One Saturday, the two friends started walking towards each other at 8:00 am. Jason walks at a speed of 4 miles per hour, while Emma walks at 4.5 miles per hour. After 3 hours, how far apart will they be?\n\nA. 25.5 miles \xa0\xa0 B. 23.0 miles \xa0\xa0 C. 24.5 miles \xa0\xa0 D. 24.0 miles \xa0\xa0 E. 26.0 miles')
# ('18', 'Coordinates grid showing:\n\n![A coordinate grid with x and y axes ranging from 0 to 8. Five points are plotted and labeled: Library at (1, 6), Playing field at (4, 6), Science Lab at (2, 3), Classroom at (6, 4), and Stairs at (5, 1).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637977/y5wqknwl4cmrdbrd0xpk.jpg)\n\n| Location      | Coordinate |\n|---------------|------------|\n| Library       | (1, 6)     |\n| Playing field | (4, 6)     |\n| Science Lab   | (2, 3)     |\n| Classroom     | (6, 4)     |\n| Stairs        | (5, 1)     |\n\nA coordinate grid with x and y axes ranging from 0 to 8. Five points are plotted and labeled: Library at (1, 6), Playing field at (4, 6), Science Lab at (2, 3), Classroom at (6, 4), and Stairs at (5, 1).\n\nWhich coordinate is the playing field?\n\nA. (2, 3) \xa0\xa0 B. (6, 4) \xa0\xa0 C. (5, 1) \xa0\xa0 D. (4, 6) \xa0\xa0 E. (1, 6)')
# ('19', 'Evaluate:\n\n$$(12 \\div 16) \\div (3 \\div 4) \\times (8 \\times 5) \\div 4$$\n\nA. 52 \xa0\xa0 B. 62 \xa0\xa0 C. 48 \xa0\xa0 D. 54 \xa0\xa0 E. 40')
# ('20', 'Larry bought 12 new football trading cards to add to his collection. The next day, his dog ate half of his collection. Now there are 24 cards left. How many cards did Larry originally have before buying the 12 new cards?\n\nA. 32 \xa0\xa0 B. 40 \xa0\xa0 C. 36 \xa0\xa0 D. 48 \xa0\xa0 E. 58')
# ('21', 'Put these numbers in order from the biggest to the smallest.\n\n0.752 \xa0 0.7 \xa0 0.472 \xa0 0.637 \xa0 0.605\n\n- A. 0.7, 0.752, 0.637, 0.605, 0.472\n- B. 0.752, 0.7, 0.637, 0.605, 0.472\n- C. 0.472, 0.605, 0.637, 0.7, 0.752\n- D. 0.637, 0.7, 0.752, 0.605, 0.472\n- E. 0.752, 0.7, 0.605, 0.637, 0.472')
# ('22', 'The circle is divide into 8 equal sectors.\n\n![A circle divided into 8 equal sectors. Point L is on the left edge, and point M is on the right edge. A horizontal line segment connects L and M, passing through the center of the circle.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637963/fxdt57zvyqhk0x8a22ep.jpg)\n\nA circle divided into 8 equal sectors. Point L is on the left edge, and point M is on the right edge. A horizontal line segment connects L and M, passing through the center of the circle.\n\nWhat is the largest angle between point L and point M (in degrees)?\n\n- A.  $125^\\circ$\n- B.  $145^\\circ$\n- C.  $90^\\circ$\n- D.  $120^\\circ$\n- E.  $135^\\circ$')
# ('23', "100 children were asked whether they like baseball, football and basketball. Their answers are shown in this diagram :\n\n![A Venn diagram with three overlapping circles. The left circle is labeled 'Like baseball', the right circle is labeled 'Like football', and the bottom circle is labeled 'Like basketball'. The numbers in the regions are: 10 (baseball only), 13 (baseball and football only), 14 (football only), 18 (baseball and basketball only), 16 (all three sports), 12 (football and basketball only), and 17 (basketball only).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637966/ukuxru5vtv6cd7ku4fpj.jpg)\n\nA Venn diagram with three overlapping circles. The left circle is labeled 'Like baseball', the right circle is labeled 'Like football', and the bottom circle is labeled 'Like basketball'. The numbers in the regions are: 10 (baseball only), 13 (baseball and football only), 14 (football only), 18 (baseball and basketball only), 16 (all three sports), 12 (football and basketball only), and 17 (basketball only).\n\nHow many children like both basketball and baseball, but NOT football?\n\n- A. 16\n- B. 18\n- C. 10\n- D. 17\n- E. 13")
# ('24', 'Which fraction of 4 hours is 72 minutes?\n\nA.  $\\frac{1}{3}$  \xa0\xa0\xa0\xa0 B.  $\\frac{1}{6}$  \xa0\xa0\xa0\xa0 C.  $\\frac{1}{5}$  \xa0\xa0\xa0\xa0 D.  $\\frac{3}{10}$  \xa0\xa0\xa0\xa0 E.  $\\frac{1}{4}$')
# ('25', '4 2 1 6 3 5\n\nIn the six-digit number 4 2 1 6 3 5, the "1" stands for 1 thousand. What does the "6" stand for?\n\nA. 60 \xa0\xa0\xa0\xa0 B. 60000 \xa0\xa0\xa0\xa0 C. 600 \xa0\xa0\xa0\xa0 D. 421600 \xa0\xa0\xa0\xa0 E. 6000')
# ('26', "This graph shows the number of sandwich sold by a shop over five weeks.\n\n![Bar graph showing the number of sandwiches sold over five weeks. The y-axis is labeled 'Number of sandwich' and ranges from 0 to 60 in increments of 10. The x-axis is labeled 'Number of weeks' and shows categories W-1, W-2, W-3, W-4, and W-5. The bars show the following values: W-1: 30, W-2: 60, W-3: 35, W-4: 20, W-5: 45.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637918/c1k1xwvuuofllhsso1fx.jpg)\n\n| Week | Number of sandwiches |\n|------|----------------------|\n| W-1  | 30                   |\n| W-2  | 60                   |\n| W-3  | 35                   |\n| W-4  | 20                   |\n| W-5  | 45                   |\n\nBar graph showing the number of sandwiches sold over five weeks. The y-axis is labeled 'Number of sandwich' and ranges from 0 to 60 in increments of 10. The x-axis is labeled 'Number of weeks' and shows categories W-1, W-2, W-3, W-4, and W-5. The bars show the following values: W-1: 30, W-2: 60, W-3: 35, W-4: 20, W-5: 45.\n\nHow many more sandwiches were sold in Week 5 than in Week 1?\n\nA. 15 \xa0\xa0\xa0\xa0 B. 25 \xa0\xa0\xa0\xa0 C. 10 \xa0\xa0\xa0\xa0 D. 20 \xa0\xa0\xa0\xa0 E. 5")
# ('27', 'Tom packed his backpack for a weekend camping trip. It contained: a thermos of coffee, three sandwiches, four oranges, a bunch of grapes, and a pack of crackers. He also packed a jacket and a sleeping bag. Roughly, how much is the backpack likely to weigh?\n\nA. 4 kg \xa0\xa0\xa0\xa0 B. 6 kg \xa0\xa0\xa0\xa0 C. 5 kg \xa0\xa0\xa0\xa0 D. 2 kg \xa0\xa0\xa0\xa0 E. 3 kg')
# ('28', 'Work out the difference between given pair of times and write your answer in hours and minutes.\n\n**6 : 42 PM**\n\n**10 : 57 PM**\n\n- A. 4 hours and 10 minutes\n- B. 3 hours and 45 minutes\n- C. 4 hours and 30 minutes\n- D. 4 hours and 15 minutes\n- E. 3 hours and 50 minutes')
# ('29', 'Find the LCM of 36, 54, and 72.\n\n- A. 432\n- B. 216\n- C. 648\n- D. 576\n- E. 324')
# ('30', 'Find the HCF of 56, 84, and 112.\n\n- A. 14\n- B. 35\n- C. 7\n- D. 28\n- E. 6')
# ('31', 'The following numbers represent the scores of students in a class:\n\n54 55 67 67 67 72 75 80 80 82 82 90 90 95 100\n\nWhat are the range and the mode?\n\n- A. 45 & 67\n- B. 46 & 82\n- C. 50 & 75\n- D. 49 & 72\n- E. 46 & 67')
# ('32', 'Olivia leaves her home at 11:30 a.m. She travels to her destination, which is 90 miles away, at an average speed of 30 mph. At what time does she reach her destination?\n\n- A. 2:00 p.m.\n- B. 3:30 p.m.\n- C. 2:30 p.m.\n- D. 3:00 p.m.\n- E. 2:15 p.m.')
# ('33', 'The table below shows the number of hours Lily worked this week at her job. She earns £18 per hour.\n\n| Days      | Hours worked |\n|-----------|--------------|\n| Monday    | 7 hours      |\n| Wednesday | 5 hours      |\n| Friday    | 8 hours      |\n\nHow much will Lily get paid for the hours she worked this week?\n\nA. £300 \xa0\xa0\xa0\xa0 B. £250 \xa0\xa0\xa0\xa0 C. £360 \xa0\xa0\xa0\xa0 D. £320 \xa0\xa0\xa0\xa0 E. £270')
# ('34', 'In a pack of 6 balls, 3 are red. How many red balls will be in a pack of 36 balls?\n\nA. 15 \xa0\xa0\xa0\xa0 B. 14 \xa0\xa0\xa0\xa0 C. 10 \xa0\xa0\xa0\xa0 D. 12 \xa0\xa0\xa0\xa0 E. 18')
# ('35', "![A 2D shape consisting of a vertical rectangle with three horizontal rectangular cutouts, creating a shape similar to a stylized letter 'E' or a staircase.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638019/rczupe6ijunetw0pjjfg.jpg)\n\nA 2D shape consisting of a vertical rectangle with three horizontal rectangular cutouts, creating a shape similar to a stylized letter 'E' or a staircase.\n\nHow many lines of symmetry does this 2D shape have?\n\nA. 4 \xa0\xa0\xa0\xa0 B. 1 \xa0\xa0\xa0\xa0 C. 3 \xa0\xa0\xa0\xa0 D. 5 \xa0\xa0\xa0\xa0 E. 2")
# ('36', 'James has two ropes, one 42 metres long and the other 56 metres long. He wants to cut them into equal lengths with no leftover rope. What is the longest length of rope he can cut them all to?\n\nA. 16m\n\nB. 18m\n\nC. 12m\n\nD. 14m\n\nE. 10m')
# ('37', 'The number of hours spent by students on homework last week are shown below:\n\n![star symbol](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637902/ztfohg5vjj9rmcunrdbz.jpg) = 2 hour\n\n| Day   | Number of hours spent                                                                                                |\n|-------|----------------------------------------------------------------------------------------------------------------------|\n| Ben   | <img alt="three stars" data-bbox="369 334 512 376" src="https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637979/o7qekcy4zko4uzs4y59k.jpg"/>                  |\n| Evan  | <img alt="two stars and one triangle" data-bbox="369 390 440 432" src="https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637950/ucwjg9a5uksqfawztboa.jpg"/>   |\n| Alex  | <img alt="three stars and one triangle" data-bbox="369 446 496 488" src="https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638027/yxwiyad4birkrqlnwm1d.jpg"/> |\n| Clara | <img alt="two stars" data-bbox="369 503 460 544" src="https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637961/tzlqbtiszx8llpcmxmpk.jpg"/>                    |\n\nHow many more hours did Alex spend on homework than Evan?\n\nA. 1 hour\n\nB. 2.5 hours\n\nC. 2 hours\n\nD. 3 hours\n\nE. 1.5 hours')
# ('38', 'A car travels 450 kilometers in 360 minutes. What is its average speed in kilometres per hour?\n\nA. 60 km/h\n\nB. 95 km/h\n\nC. 70 km/h\n\nD. 82 km/h\n\nE. 75 km/h')
# ('39', 'Convert this fraction to its decimal equivalent.\n\n$$\\frac{27}{50}$$\n\nA. 0.44\n\nB. 0.68\n\nC. 0.27\n\nD. 0.64\n\nE. 0.54')
# ('40', 'Work out the difference between the given times.\n\n![An analog clock face showing the time 10:10. The hour hand is between 10 and 11, and the minute hand is at 2.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637971/n2scjjmvvicg86hupogw.jpg)\n\nAn analog clock face showing the time 10:10. The hour hand is between 10 and 11, and the minute hand is at 2.\n\n![An analog clock face showing the time 2:40. The hour hand is between 2 and 3, and the minute hand is at 8.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637899/pnrayzz3wfobxoo5vdsm.jpg)\n\nAn analog clock face showing the time 2:40. The hour hand is between 2 and 3, and the minute hand is at 8.\n\nWhat is the answer in hours and minutes?\n\n**A.** 3 hrs 15 mins \xa0 **B.** 2 hrs 50 mins \xa0 **C.** 2 hrs 45 mins \xa0 **D.** 2 hrs 55 mins \xa0 **E.** 2 hrs 40 mins')
# ('41', "Line AB and CD are parallel.\n\n![A geometry diagram showing two parallel lines, AB and CD, intersected by a transversal line EF. Line AB is the top horizontal line, and line CD is the bottom horizontal line. Line EF is a diagonal line crossing both. At the intersection of EF and AB, an angle is labeled 70° and another is labeled 2x - 10°. At the intersection of EF and CD, an angle is labeled z° and another is labeled y°.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637975/kzgxbfmvwd00jfjnnyem.jpg)\n\nA geometry diagram showing two parallel lines, AB and CD, intersected by a transversal line EF. Line AB is the top horizontal line, and line CD is the bottom horizontal line. Line EF is a diagonal line crossing both. At the intersection of EF and AB, an angle is labeled 70° and another is labeled 2x - 10°. At the intersection of EF and CD, an angle is labeled z° and another is labeled y°.\n\nFind the value of 'x', 'y' and 'z'.\n\n**A.** 45°, 120°, 80°  \n**B.** 50°, 110°, 80°  \n**C.** 45°, 130°, 70°  \n**D.** 40°, 120°, 60°  \n**E.** 40°, 110°, 70°")
# ('42', 'Sarah starts with a temperature of  $40^{\\circ}\\text{C}$  for her first experiment. Each time she repeats the experiment, the temperature is  $5^{\\circ}\\text{C}$  cooler than before. At what temperature did she carry out her sixth experiment?\n\nA.  $12^{\\circ}\\text{C}$  \xa0\xa0\xa0\xa0 B.  $18^{\\circ}\\text{C}$  \xa0\xa0\xa0\xa0 C.  $25^{\\circ}\\text{C}$  \xa0\xa0\xa0\xa0 D.  $15^{\\circ}\\text{C}$  \xa0\xa0\xa0\xa0 E.  $24^{\\circ}\\text{C}$')
# ('43', 'John is facing East. He turns clockwise through  $180^{\\circ}$ .\n\n![A compass rose diagram showing eight directions: North (N), South (S), East (E), and West (W) are labeled. Diagonal directions are also present but not labeled. An arrow points North.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637934/w0kauk3ohlf8nhgukv9o.jpg)\n\nA compass rose diagram showing eight directions: North (N), South (S), East (E), and West (W) are labeled. Diagonal directions are also present but not labeled. An arrow points North.\n\nWhich direction does he face now?\n\nA. NW \xa0\xa0\xa0\xa0 B. E \xa0\xa0\xa0\xa0 C. S \xa0\xa0\xa0\xa0 D. W \xa0\xa0\xa0\xa0 E. NE')
# ('44', 'The sum of the first five square numbers is 55. What is the sum of the first eight square numbers?\n\nA. 204 \xa0\xa0\xa0\xa0 B. 175 \xa0\xa0\xa0\xa0 C. 155 \xa0\xa0\xa0\xa0 D. 230 \xa0\xa0\xa0\xa0 E. 140')
# ('45', 'Change the order of the digits in 5639 to make the largest number possible. What is the largest number you can form?\n\nA. 9635 \xa0\xa0\xa0\xa0 B. 9356 \xa0\xa0\xa0\xa0 C. 9653 \xa0\xa0\xa0\xa0 D. 9563 \xa0\xa0\xa0\xa0 E. 9536')
# HEADING ## NON-VERBAL REASONING
#
# HEADING ### SECTION 1
# ('1', '![A circle containing a pentagon, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638001/nslfyb8ah3z2hzgoon3d.jpg)\n\nA circle containing a pentagon, which contains a black dot.\n\nA\n\n![A dashed circle containing a pentagon, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638022/rhdzfue7ekzkvhcw3ans.jpg)\n\nA dashed circle containing a pentagon, which contains a black dot.\n\nB\n\n![A circle containing a pentagon, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638030/cn9yb5cuswxyuu6eoxaq.jpg)\n\nA circle containing a pentagon, which contains a black dot.\n\nC\n\n![A circle containing a pentagon, which contains a black square.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637922/diovlyfs0bi4yyyqiehc.jpg)\n\nA circle containing a pentagon, which contains a black square.\n\nD\n\n![A dashed circle containing a pentagon, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637952/hxflo5ipoqltyzhglymz.jpg)\n\nA dashed circle containing a pentagon, which contains a black dot.\n\nE')
# ('2', '![A parallelogram containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638034/jobxfpjsvn1lf7kpfubm.jpg)\n\nA parallelogram containing a square, which contains a black dot.\n\nA\n\n![A parallelogram containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637930/qfnhkll9gya8rwnykwus.jpg)\n\nA parallelogram containing a square, which contains a black dot.\n\nB\n\n![A rectangle containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638028/hljfq71dljexytz5vynj.jpg)\n\nA rectangle containing a square, which contains a black dot.\n\nC\n\n![A parallelogram containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637966/q73rblgxve4kybgxn2em.jpg)\n\nA parallelogram containing a square, which contains a black dot.\n\nD\n\n![A parallelogram containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638023/qjnkqdslr9c7x8jkbqq5.jpg)\n\nA parallelogram containing a square, which contains a black dot.\n\nE')
# ('3', '![A pentagon containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637970/diigk5bh4ojtap75ihnb.jpg)\n\nA pentagon containing a square, which contains a black dot.\n\nA\n\n![A pentagon containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637913/t0swyr76gquvn8nldzvq.jpg)\n\nA pentagon containing a square, which contains a black dot.\n\nB\n\n![A pentagon containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637986/ofosttnlndeqseiahwil.jpg)\n\nA pentagon containing a square, which contains a black dot.\n\nC\n\n![A pentagon containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637916/ajea2kxeh4fwp6uaoxu5.jpg)\n\nA pentagon containing a square, which contains a black dot.\n\nD\n\n![A pentagon containing a square, which contains a black dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637997/rnoo19ckoovnr4oqe62s.jpg)\n\nA pentagon containing a square, which contains a black dot.\n\nE')
# ...
# ('31', '![Four arrows pointing left: AT (hatched), BS (solid), AK (solid), DK (solid).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638007/qccjprwjcnzrfkzrhyu8.jpg)\n\nFour arrows pointing left: AT (hatched), BS (solid), AK (solid), DK (solid).\n\n![A solid arrow pointing left.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637943/dml8wvhiqp9yocoalrnm.jpg)\n\nA solid arrow pointing left.\n\n DS  \nA\n\n DK  \nB\n\n DT  \nC\n\n AT  \nD\n\n BS  \nE')
# ('32', '![Four shapes: RT (solid black triangle), RD (solid black triangle), BS (hatched square), BS (hatched triangle).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638014/u0z1fevratwtwdjgpapt.jpg)\n\nFour shapes: RT (solid black triangle), RD (solid black triangle), BS (hatched square), BS (hatched triangle).\n\n![A solid square and a solid triangle.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637910/yyypnezmztrzw9kjlcwm.jpg)\n\nA solid square and a solid triangle.\n\n RT  \nA\n\n BT  \nB\n\n RD  \nC\n\n BD  \nD\n\n BS  \nE')
# ('33', '![Four shapes: FKP (hatched triangle with circle), XSE (solid circle with dot), FSA (solid triangle with dot), JKE (solid square with circle).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638015/xfhmjkvvxtgjjeda9bwe.jpg)\n\nFour shapes: FKP (hatched triangle with circle), XSE (solid circle with dot), FSA (solid triangle with dot), JKE (solid square with circle).\n\n![A solid circle with a dot.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637981/so2vrxzfh6rssspzuk9l.jpg)\n\nA solid circle with a dot.\n\n XSE  \nA\n\n XRA  \nB\n\n XKP  \nC\n\n MSE  \nD\n\n JKP  \nE')
# ('34', '![Four shapes: TQM (two circles with lines), TPW (two squares with lines), FQS (one circle with line).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637907/b3fjj9hltbu1zeauro4g.jpg)\n\nFour shapes: TQM (two circles with lines), TPW (two squares with lines), FQS (one circle with line).\n\n![A single circle with a line.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637928/uuhhapzg3leo9df7prjq.jpg)\n\nA single circle with a line.\n\n FQW  \nA\n\n TPM  \nB\n\n FQM  \nC\n\n FPW  \nD\n\n FPM  \nE')
# ('35', '![Four shapes: SV (solid crown), MK (solid crown), SO (solid crown), DK (dashed crown).](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638026/grpe5b8iaeq5wakduapf.jpg)\n\nFour shapes: SV (solid crown), MK (solid crown), SO (solid crown), DK (dashed crown).\n\n![A solid crown.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637904/g1zw0nsdl2de8l9go9vn.jpg)\n\nA solid crown.\n\n SV  \nA\n\n MV  \nB\n\n DO  \nC\n\n DK  \nD\n\n SK  \nE')
# HEADING ### SECTION 4
#
# HEADING ### P1
#
# HEADING ### P2
# ('36', "![A sequence of four 2x2 grids. Grid 1: Top-left is a crescent moon, top-right is 'B', bottom-left is 'T', bottom-right is empty. Grid 2: Top-left is a staircase shape, top-right is 'L', bottom-left is empty, bottom-right is 'S'. Grid 3: Top-left is a crescent moon, top-right is 'B', bottom-left is 'S', bottom-right is empty. Grid 4: Top-left is a staircase shape, top-right is empty, bottom-left is 'L', bottom-right is empty.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637958/dnnymhpbtnpsk7il40nd.jpg)\n\nA sequence of four 2x2 grids. Grid 1: Top-left is a crescent moon, top-right is 'B', bottom-left is 'T', bottom-right is empty. Grid 2: Top-left is a staircase shape, top-right is 'L', bottom-left is empty, bottom-right is 'S'. Grid 3: Top-left is a crescent moon, top-right is 'B', bottom-left is 'S', bottom-right is empty. Grid 4: Top-left is a staircase shape, top-right is empty, bottom-left is 'L', bottom-right is empty.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| L | B | L | L | B |\n| S | S | T | V | T |\n| A | B | C | D | E |")
# ('37', "![A sequence of four 2x2 grids. Grid 1: Top-left is a thick left-pointing arrow, top-right is 'A', bottom-left is 'X', bottom-right is empty. Grid 2: Top-left is a staircase shape, top-right is 'S', bottom-left is empty, bottom-right is 'Y'. Grid 3: Top-left is a thick left-pointing arrow, top-right is 'A', bottom-left is 'Z', bottom-right is empty. Grid 4: Top-left is a thick left-pointing arrow, top-right is empty, bottom-left is 'L', bottom-right is empty.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637995/bthenialpcpjcw130j41.jpg)\n\nA sequence of four 2x2 grids. Grid 1: Top-left is a thick left-pointing arrow, top-right is 'A', bottom-left is 'X', bottom-right is empty. Grid 2: Top-left is a staircase shape, top-right is 'S', bottom-left is empty, bottom-right is 'Y'. Grid 3: Top-left is a thick left-pointing arrow, top-right is 'A', bottom-left is 'Z', bottom-right is empty. Grid 4: Top-left is a thick left-pointing arrow, top-right is empty, bottom-left is 'L', bottom-right is empty.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | A | S | S | A |\n| X | Z | Y | X | Y |\n| A | B | C | D | E |")
# ('38', "![A sequence of five 2x2 grids. Grid 1: Top-left is a hexagon with a black circle, top-right is 'G', bottom-left is 'E', bottom-right is empty. Grid 2: Top-left is a hexagon with diagonal lines, top-right is 'L', bottom-left is empty, bottom-right is 'J'. Grid 3: Top-left is a hexagon with diagonal lines and a grey circle, top-right is 'R', bottom-left is 'J', bottom-right is empty. Grid 4: Top-left is a hexagon with a grey circle, top-right is 'R', bottom-left is 'E', bottom-right is empty. Grid 5: Top-left is a hexagon with diagonal lines and a black circle, top-right is empty, bottom-left is 'L', bottom-right is empty.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637982/zgpaivm4q7ah5q13fhhi.jpg)\n\nA sequence of five 2x2 grids. Grid 1: Top-left is a hexagon with a black circle, top-right is 'G', bottom-left is 'E', bottom-right is empty. Grid 2: Top-left is a hexagon with diagonal lines, top-right is 'L', bottom-left is empty, bottom-right is 'J'. Grid 3: Top-left is a hexagon with diagonal lines and a grey circle, top-right is 'R', bottom-left is 'J', bottom-right is empty. Grid 4: Top-left is a hexagon with a grey circle, top-right is 'R', bottom-left is 'E', bottom-right is empty. Grid 5: Top-left is a hexagon with diagonal lines and a black circle, top-right is empty, bottom-left is 'L', bottom-right is empty.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| R | L | R | G | G |\n| E | J | J | E | J |\n| A | B | C | D | E |")
# ('39', "![A sequence of five 2x2 grids. Grid 1: Top-left is a diamond with three horizontal lines, top-right is 'Y', bottom-left is 'D', bottom-right is empty. Grid 2: Top-left is a diamond with three horizontal lines, top-right is 'Y', bottom-left is 'B', bottom-right is empty. Grid 3: Top-left is a speech bubble with three horizontal lines, top-right is 'S', bottom-left is empty, bottom-right is 'A'. Grid 4: Top-left is a speech bubble with three horizontal lines, top-right is 'L', bottom-left is 'D', bottom-right is empty. Grid 5: Top-left is a speech bubble with three horizontal lines, top-right is empty, bottom-left is 'L', bottom-right is empty.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637911/t6nawqqstxmulflwxwfu.jpg)\n\nA sequence of five 2x2 grids. Grid 1: Top-left is a diamond with three horizontal lines, top-right is 'Y', bottom-left is 'D', bottom-right is empty. Grid 2: Top-left is a diamond with three horizontal lines, top-right is 'Y', bottom-left is 'B', bottom-right is empty. Grid 3: Top-left is a speech bubble with three horizontal lines, top-right is 'S', bottom-left is empty, bottom-right is 'A'. Grid 4: Top-left is a speech bubble with three horizontal lines, top-right is 'L', bottom-left is 'D', bottom-right is empty. Grid 5: Top-left is a speech bubble with three horizontal lines, top-right is empty, bottom-left is 'L', bottom-right is empty.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| L | L | Y | Y | L |\n| D | A | D | A | B |\n| A | B | C | D | E |")
# ('40', "![A sequence of five 2x2 grids. Grid 1: Top-left is a circle with two eyes, top-right is 'T', bottom-left is 'D', bottom-right is empty. Grid 2: Top-left is a circle with two eyes, top-right is 'S', bottom-left is 'P', bottom-right is empty. Grid 3: Top-left is a circle with two eyes, top-right is 'S', bottom-left is 'W', bottom-right is empty. Grid 4: Top-left is a circle with two eyes, top-right is 'Y', bottom-left is 'W', bottom-right is empty. Grid 5: Top-left is a circle with two eyes, top-right is empty, bottom-left is 'L', bottom-right is empty.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638000/bomejnjtrblmztlremjd.jpg)\n\nA sequence of five 2x2 grids. Grid 1: Top-left is a circle with two eyes, top-right is 'T', bottom-left is 'D', bottom-right is empty. Grid 2: Top-left is a circle with two eyes, top-right is 'S', bottom-left is 'P', bottom-right is empty. Grid 3: Top-left is a circle with two eyes, top-right is 'S', bottom-left is 'W', bottom-right is empty. Grid 4: Top-left is a circle with two eyes, top-right is 'Y', bottom-left is 'W', bottom-right is empty. Grid 5: Top-left is a circle with two eyes, top-right is empty, bottom-left is 'L', bottom-right is empty.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| Y | T | Y | Y | T |\n| K | P | D | P | D |\n| A | B | C | D | E |")
# ('41', "![Four 2x2 grids showing transformations of arrows. Grid 1: Horizontal arrows pointing left in top-left and bottom-right cells, 'B' in top-right, 'T' in bottom-left. Grid 2: Vertical arrows pointing up in top-left and bottom-right cells, 'L' in top-right, 'V' in bottom-left. Grid 3: Diagonal arrows pointing top-left in top-left and bottom-right cells, 'L' in top-right, 'S' in bottom-left. Grid 4: Horizontal arrows pointing left in top-left and bottom-right cells, empty cells.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637976/sixeiemo9ta1017crxkf.jpg)\n\nFour 2x2 grids showing transformations of arrows. Grid 1: Horizontal arrows pointing left in top-left and bottom-right cells, 'B' in top-right, 'T' in bottom-left. Grid 2: Vertical arrows pointing up in top-left and bottom-right cells, 'L' in top-right, 'V' in bottom-left. Grid 3: Diagonal arrows pointing top-left in top-left and bottom-right cells, 'L' in top-right, 'S' in bottom-left. Grid 4: Horizontal arrows pointing left in top-left and bottom-right cells, empty cells.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| L | L | B | L | B |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| T | S | V | V | T |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | B | C | D | E |\n|---|---|---|---|---|")
# ('42', "![Four 2x2 grids showing transformations of curved shapes. Grid 1: A curved shape in the bottom-left cell, 'S' in top-right, 'Z' in bottom-left. Grid 2: A curved shape with a dashed line in the top-right cell, 'A' in top-right, 'Y' in bottom-left. Grid 3: A curved shape with a dashed line in the top-left cell, 'A' in top-right, 'Z' in bottom-left. Grid 4: A curved shape with a dashed line in the bottom-right cell, empty cells.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637963/u0lukv8y9mnvss5ucbfk.jpg)\n\nFour 2x2 grids showing transformations of curved shapes. Grid 1: A curved shape in the bottom-left cell, 'S' in top-right, 'Z' in bottom-left. Grid 2: A curved shape with a dashed line in the top-right cell, 'A' in top-right, 'Y' in bottom-left. Grid 3: A curved shape with a dashed line in the top-left cell, 'A' in top-right, 'Z' in bottom-left. Grid 4: A curved shape with a dashed line in the bottom-right cell, empty cells.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | A | S | S | S |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| Y | Z | Z | Y | X |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | B | C | D | E |\n|---|---|---|---|---|")
# ('43', "![Five 2x2 grids showing transformations of bird-like shapes. Grid 1: Two bird shapes in the bottom-left cell, 'L' in top-right, 'I' in bottom-left. Grid 2: Two bird shapes in the bottom-left cell, 'G' in top-right, 'J' in bottom-left. Grid 3: Three bird shapes in the bottom-left cell, 'R' in top-right, 'J' in bottom-left. Grid 4: Three bird shapes in the bottom-left cell, 'R' in top-right, 'E' in bottom-left. Grid 5: Two bird shapes in the bottom-left cell, empty cells.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637899/w2xcridpstvewarvgprn.jpg)\n\nFive 2x2 grids showing transformations of bird-like shapes. Grid 1: Two bird shapes in the bottom-left cell, 'L' in top-right, 'I' in bottom-left. Grid 2: Two bird shapes in the bottom-left cell, 'G' in top-right, 'J' in bottom-left. Grid 3: Three bird shapes in the bottom-left cell, 'R' in top-right, 'J' in bottom-left. Grid 4: Three bird shapes in the bottom-left cell, 'R' in top-right, 'E' in bottom-left. Grid 5: Two bird shapes in the bottom-left cell, empty cells.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| L | G | R | G | G |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| I | I | I | E | J |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | B | C | D | E |\n|---|---|---|---|---|")
# ('44', "![Five 2x2 grids showing transformations of geometric shapes. Grid 1: A shield shape in the bottom-left cell, 'Y' in top-right, 'D' in bottom-left. Grid 2: A striped shape in the bottom-left cell, 'L' in top-right, 'B' in bottom-left. Grid 3: A black and white striped shape in the bottom-left cell, 'R' in top-right, 'C' in bottom-left. Grid 4: Two black shapes in the bottom-left cell, 'J' in top-right, 'C' in bottom-left. Grid 5: Two gray shapes in the bottom-left cell, empty cells.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770638019/q0ww7yzzhikot5skddkz.jpg)\n\nFive 2x2 grids showing transformations of geometric shapes. Grid 1: A shield shape in the bottom-left cell, 'Y' in top-right, 'D' in bottom-left. Grid 2: A striped shape in the bottom-left cell, 'L' in top-right, 'B' in bottom-left. Grid 3: A black and white striped shape in the bottom-left cell, 'R' in top-right, 'C' in bottom-left. Grid 4: Two black shapes in the bottom-left cell, 'J' in top-right, 'C' in bottom-left. Grid 5: Two gray shapes in the bottom-left cell, empty cells.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| L | J | R | L | Y |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| D | B | D | C | C |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | B | C | D | E |\n|---|---|---|---|---|")
# ('45', "![Five 2x2 grids showing transformations of 'X' shapes. Grid 1: Four 'X' shapes in the bottom-left cell, 'T' in top-right, 'D' in bottom-left. Grid 2: Four 'X' shapes in the bottom-left cell, 'S' in top-right, 'P' in bottom-left. Grid 3: Four 'X' shapes in the bottom-left cell, 'S' in top-right, 'W' in bottom-left. Grid 4: Four 'X' shapes in the bottom-left cell, 'Z' in top-right, 'D' in bottom-left. Grid 5: Four 'X' shapes in the bottom-left cell, empty cells.](https://res.cloudinary.com/dgpvwrolc/image/upload/v1770637995/wofvmecpgv9puup4akjh.jpg)\n\nFive 2x2 grids showing transformations of 'X' shapes. Grid 1: Four 'X' shapes in the bottom-left cell, 'T' in top-right, 'D' in bottom-left. Grid 2: Four 'X' shapes in the bottom-left cell, 'S' in top-right, 'P' in bottom-left. Grid 3: Four 'X' shapes in the bottom-left cell, 'S' in top-right, 'W' in bottom-left. Grid 4: Four 'X' shapes in the bottom-left cell, 'Z' in top-right, 'D' in bottom-left. Grid 5: Four 'X' shapes in the bottom-left cell, empty cells.\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| S | T | S | S | T |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| W | W | D | P | P |\n|---|---|---|---|---|\n\n|   |   |   |   |   |\n|---|---|---|---|---|\n| A | B | C | D | E |\n|---|---|---|---|---|")
